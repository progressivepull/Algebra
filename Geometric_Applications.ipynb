# %% [markdown]
# # Using Python for Algebra in Geometric Applications
# Algebra plays a crucial role in solving geometric problems, such as calculating areas, distances, and slopes. Python provides powerful tools to apply algebraic concepts to geometry using libraries like NumPy and matplotlib.

# %% [markdown]
# ## 1. Setting Up Your Environment
# Before we begin, make sure you have Python installed. You might need the following libraries:
#
# ```
#     pip install numpy matplotlib
# ```

# %% [markdown]
# ## 2. Finding the Distance Between Two Points
# The distance 𝑑 between two points $(x_1, y_1)$ and $(x_2, y_2)$ is given by:
#
# $$d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$$

# %%
import numpy as np

def distance(x1, y1, x2, y2):
    return np.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# Example
print(distance(3, 4, 7, 1))  # Output: 5.0
# Out:
# 5.0

# %% [markdown]
# ## 3. Finding the Slope of a Line
# The slope 𝑚 between two points $(x_1, y_1)$ and $(x_2, y_2)$ is given by:
#
# $$m = \frac{y_2 - y_1}{x_2 - x_1}$$

# %%
def slope(x1, y1, x2, y2):
    return (y2 - y1) / (x2 - x1)

# Example
print(slope(1, 2, 4, 8))  # Output: 2.0
# Out:
# 2.0

# %% [markdown]
# ## 4. Finding the Area of a Triangle
# The area 𝐴 of a triangle given its three vertices $(x_1, y_1)$, $(x_2, y_2)$ and $(x_3, y_3)$ is:
#
# $$A = \frac{\left| x_1(y_2 - y_3) + x_2(y_3 - y_1) + x_3(y_1 - y_2) \right|}{2}$$

# %%
def triangle_area(x1, y1, x2, y2, x3, y3):
    return abs(x1*(y2 - y3) + x2*(y3 - y1) + x3*(y1 - y2)) / 2

# Example
print(triangle_area(0, 0, 5, 0, 0, 5))  # Output: 12.5
# Out:
# 12.5

# %% [markdown]
# ## 5. Visualizing Geometric Concepts
# Let’s plot a triangle using **matplotlib** :

# %%
import matplotlib.pyplot as plt

def plot_triangle(x1, y1, x2, y2, x3, y3):
    plt.plot([x1, x2, x3, x1], [y1, y2, y3, y1], 'bo-')
    plt.fill([x1, x2, x3], [y1, y2, y3], 'cyan', alpha=0.5)
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
    plt.title("Triangle Visualization")
    plt.grid(True)
    plt.show()

# Example
plot_triangle(0, 0, 5, 0, 0, 5)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Conclusion
# Python makes algebraic applications in geometry intuitive. You can compute distances, slopes, and areas while visualizing them effortlessly. Try modifying the examples to explore different shapes and figures!

# %% [markdown]
# # [College Algebra Context](./README.md)
